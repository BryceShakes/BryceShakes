# %%
import pandas as pd
import requests
import time
import sys
import re
from bs4 import BeautifulSoup as bs
from IPython.display import display, HTML, clear_output
from datetime import datetime
from selenium import webdriver
from selenium.webdriver import FirefoxOptions
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
opts = FirefoxOptions()
opts.add_argument("--headless")
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'}

# %%
class scraper:
    opts = FirefoxOptions()
    opts.add_argument("--headless")
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'}

    @staticmethod
    def dic_to_df(dic):
        new = pd.DataFrame(dic)
        new.sort_values('pecentage_off', inplace =True, ascending = False)
        new.reset_index(drop=True, inplace = True)
        new['previous_price'] = new['previous_price'].apply(lambda x: "£{:.2f}".format((x)))
        new['price'] = new['price'].apply(lambda x: "£{:.2f}".format((x)))
        new['pecentage_off'] = new['pecentage_off'].apply(lambda x: "{:.0f}%".format(x))

        return new
        
    @staticmethod
    def display(df, show = 50):

        def path_to_image_html(path):
            return '<img src="'+ path + '" width="150" >'

        def make_clickable(val):
            # target _blank to open new window
            return '<a target="_blank" href="{}">{}</a>'.format(val, val)
    
        if isinstance(df, dict):
            df = scraper.dic_to_df(df)
        
        show = min(show, len(df))
        format_dic = {'img_link':path_to_image_html, 'item_link':make_clickable}
        display(HTML(df.head(show).to_html(escape=False, formatters=format_dic, index = False)))
        
    @staticmethod
    def bananafingers(pages = 99,
                      display = False,
                      dic = {
                          'item_name':[],
                          'price':[],
                          'pecentage_off':[],
                          'previous_price':[],
                          'img_link':[],
                          'item_link':[]}
                     ):
            
        for pg in range(1, pages + 1):
            url = f'https://bananafingers.co.uk/outlet?p={pg}' # loop through each outlet page
            page = requests.get(url, headers = scraper.headers) # call website
            if page.status_code != 200:
                page = requests.get(url, headers = headers) # try again
            if page.status_code != 200:
                page = requests.get(url, headers = headers) # try again again
            if page.status_code != 200:
                break # give up
            soup = bs(page.text, 'html.parser') # parse html into text
            if soup.find('div', class_ ='message info empty'): #stop if the returned html contains an empty warning (ran out of sale items)
                break
            all = soup.findAll('li', class_ = 'item product product-item') # find html class for sale items, gather all classes into list
        
            for i in all: # each sale item, get relevant info from html 
                pecentage_off = float(i.find('span').get_text().strip().replace('%', ''))
                dic['pecentage_off'].append(pecentage_off)
                dic['img_link'].append( i.find('img')['src'])
                dic['item_name'].append(i.find(class_='product-item-link').get_text().strip())
                dic['item_link'].append( i.find(class_='product-item-link')['href'])
                price = float(i.find(class_='price').get_text().strip('£'))
                dic['price'].append(price)
                dic['previous_price'].append(price / (1-(pecentage_off/100)))

        if display:
            scraper.display(dic)
        
        return dic

    @staticmethod
    def rockrun(display = False,
                dic = {
                    'item_name':[],
                    'price':[],
                    'pecentage_off':[],
                    'previous_price':[],
                    'img_link':[],
                    'item_link':[]}
               ):
        
        browser = webdriver.Firefox(options=scraper.opts)
        
        browser.get('https://rockrun.com/collections/climbing-mountaineering-deals') # use selenium (via firefox instance) to connect to rockrun
        time.sleep(1)
        
        body = browser.find_element(By.CSS_SELECTOR, "body") # need to scroll down to access all sale items, so click somewhere that wont change the page, and scroll down
        no_of_pagedowns = 50
        
        while no_of_pagedowns:
            body.send_keys(Keys.PAGE_DOWN) # send pg_down key press to firefox instance
            time.sleep(1) #it loads new thingies so give it a mo
            no_of_pagedowns-=1
        
        soup = bs(browser.page_source) # convert html from selenium to parsed text
        browser.quit()
        
        all = soup.findAll('div', class_='product-wrap') # find html class for sale items, gather all classes into list
        
        for i in all: # each sale item, get relevant info from html 
            dic['item_name'].append(i.find(class_ ='product-thumbnail__title').get_text())
            price = float(i.find(class_ = 'money').get_text().strip().replace('£',''))
            dic['price'].append(price)
            previous_price = price if i.find(class_ = 'product-thumbnail__was-price compare-at-price') is None else float(i.find(class_ = 'product-thumbnail__was-price compare-at-price').get_text().strip().replace('£',''))
            dic['previous_price'].append(previous_price)
            dic['pecentage_off'].append((1 - (price/previous_price))*100)
            dic['item_link'].append(f"https://rockrun.com{i.find('a')['href']}")
            dic['img_link'].append(f"https://{i.find('img')['src'].strip('/')}")
        
        if display:
            scraper.display(dic)
    
        return dic

    def climbers_shop(display = False,
                      dic = {
                          'item_name':[],
                          'price':[],
                          'pecentage_off':[],
                          'previous_price':[],
                          'img_link':[],
                          'item_link':[]}
                     ):

        browser = webdriver.Firefox(options=scraper.opts)
        browser.get('https://www.climbers-shop.com/climbing-equipment/eol/instock')
        time.sleep(1)
        
        body = browser.find_element(By.CSS_SELECTOR, "body")
        no_of_pagedowns = 30
        
        while no_of_pagedowns:
            body.send_keys(Keys.PAGE_DOWN) 
            time.sleep(1)
            no_of_pagedowns-=1
        
        soup = bs(browser.page_source)
        browser.quit()
        
        pattern2 = re.compile(r'item col-facetItem ctrPad16$')
        all = soup.findAll('div', class_ = pattern2)
        
        for i in all:
            if i.find('div', class_ = re.compile(r'col-1 pricing$')).find(id='lblwas'): #some items arnt actually on sale idk, so just skip if i cant return a prev price
                dic['item_name'].append(i.find('a', class_ = re.compile(r'col-1 frItemName$')).get_text())
                dic['price'].append(float(i.find('div', class_ = re.compile(r'col-1 pricing$')).find(id='lblNow').get_text().strip().replace('£','')))
                dic['previous_price'].append(float(i.find('div', class_ = re.compile(r'col-1 pricing$')).find(id='lblwas').get_text().strip().replace('£','')))
                dic['pecentage_off'].append(float(i.find('div', class_ = re.compile(r'col-1 pricing$')).find(class_='percentOff-betterSearch').get_text().split(' ')[1].replace('%', '')))
                dic['item_link'].append(f"https://www.climbers-shop.com{i.find('a', class_ = re.compile(r'col-1 frItemName$'))['href']}")
                dic['img_link'].append(f"https://www.climbers-shop.com{i.find('img')['data-src']}")
        
        if display:
            scraper.display(dic)
    
        return dic
        
    def gooutdoors(pages = 99,
                   display = False,
                   dic = {
                       'item_name':[],
                       'price':[],
                       'pecentage_off':[],
                       'previous_price':[],
                       'img_link':[],
                       'item_link':[]}
                     ):
        browser = webdriver.Firefox(options=scraper.opts)
        pattern = re.compile(r'^product-item')
        
        for pg in range(1,pages + 1):
            url = f'https://www.gooutdoors.co.uk/climbing/sal:view/page{pg}.html'
            browser.get(url)
            time.sleep(1)
            soup = bs(browser.page_source)
            if soup.find(id='noPage'): #stop if the returned html contains an empty warning (ran out of sale items) or pgs >= 100 (just in case)
                break
            all = soup.find('div', class_ = 'productlist_grid').findAll('article', class_ = pattern)
        
            for i in all:
                sale_text = i.find(class_='offer-text').find().get_text()
                if '%' in sale_text:
                    off = float([i for i in sale_text.split(' ') if '%' in i][0].replace('%', ''))/100
                else:
                    off = 0
                dic['item_link'].append(f"https://www.gooutdoors.co.uk{i.find('a')['href']}")
                dic['img_link'].append(i.find('img')['src'])
                dic['item_name'].append(i.find('h2').get_text())
                price = float(i.find(class_='loyalty-price').get_text().partition('£')[2]) * (1-off)
                dic['price'].append(price)
                previous_price = float(i.find(class_='retail-price').get_text().partition('£')[2])
                dic['previous_price'].append(previous_price)
                dic['pecentage_off'].append((1 - (price/previous_price))*100)
            time.sleep(5) # gooutdoors doesnt like being called lots :(
        browser.quit()
        
        if display:
            scraper.display(dic)
    
        return dic


    @staticmethod
    def alpine_trek(pages = 99,
                    display = False,
                    dic = {
                        'item_name':[],
                        'price':[],
                        'pecentage_off':[],
                        'previous_price':[],
                        'img_link':[],
                        'item_link':[]}
                     ):
        browser = webdriver.Firefox(options=scraper.opts)
        url = f'https://www.alpinetrek.co.uk/outlet/climbing/1/'
        browser.get(url)
        time.sleep(1)
        soup = bs(browser.page_source)

        items = int(re.findall('\d+|$', soup.find(class_ ='product-amount inline highlight-2').get_text())[0])
        pgs = items/len(soup.findAll(class_='product-item product-fallback'))
        
        for pg in range(1,min(pages+1,int(pgs)+2)):
            url = f'https://www.alpinetrek.co.uk/outlet/climbing/{pg}/'
            browser.get(url)
            time.sleep(1)
            soup = bs(browser.page_source)
            all = soup.findAll(class_='product-item product-fallback')
        
            for i in all:
                if i.find(class_='product-price').find(class_='uvp'):
                    dic['item_link'].append(i.find(class_='product-link')['href'])
                    dic['img_link'].append(i.find(class_='product-image')['src'])
                    dic['item_name'].append(i.find(class_='manufacturer-title').get_text() + i.find(class_='product-title').get_text().replace('\n',' '))
                    previous_price = float(re.findall(r"\d+\.\d+", i.find(class_='product-price').find(class_='uvp').get_text())[0])
                    price = float(re.findall(r"\d+\.\d+", i.find(class_='product-price').find(class_='price high-light').get_text())[0])
                    dic['price'].append(price)
                    dic['previous_price'].append(previous_price)
                    dic['pecentage_off'].append((1 - (price/previous_price))*100)
        browser.quit()
        
        if display:
            scraper.display(dic)
    
        return dic
        
    @staticmethod
    def scrape(display = True):
        dic = scraper.bananafingers()
        dic = scraper.rockrun(dic = dic)
        dic = scraper.climbers_shop(dic = dic)
        dic = scraper.gooutdoors(dic = dic)
        
        df = scraper.dic_to_df(dic)
        
        if display:
            scraper.display(df)
            
        return df

# %%
url = f'https://www.alpinetrek.co.uk/outlet/climbing/1/' # loop through each outlet page
page = requests.get(url, headers = headers)
page.status_code

# %%
dic = {
       'item_name':[],
       'price':[],
       'pecentage_off':[],
       'previous_price':[],
       'img_link':[],
       'item_link':[]}

browser = webdriver.Firefox(options=opts)
url = f'https://www.alpinetrek.co.uk/outlet/climbing/1/'
browser.get(url)
time.sleep(1)
soup = bs(browser.page_source)

items = int(re.findall('\d+|$', soup.find(class_ ='product-amount inline highlight-2').get_text())[0])
pages = items/len(soup.findAll(class_='product-item product-fallback'))
for pg in range(1,int(pages)+2):
    url = f'https://www.alpinetrek.co.uk/outlet/climbing/{pg}/'
    browser.get(url)
    time.sleep(1)
    soup = bs(browser.page_source)
    all = soup.findAll(class_='product-item product-fallback')

    for i in all:
        if i.find(class_='product-price').find(class_='uvp'):
            dic['item_link'].append(i.find(class_='product-link')['href'])
            dic['img_link'].append(i.find(class_='product-image')['src'])
            dic['item_name'].append(i.find(class_='manufacturer-title').get_text() + i.find(class_='product-title').get_text().replace('\n',' '))
            previous_price = float(re.findall(r"\d+\.\d+", i.find(class_='product-price').find(class_='uvp').get_text())[0])
            price = float(re.findall(r"\d+\.\d+", i.find(class_='product-price').find(class_='price high-light').get_text())[0])
            dic['price'].append(price)
            dic['previous_price'].append(previous_price)
            dic['pecentage_off'].append((1 - (price/previous_price))*100)
# Out:
# The geckodriver version (0.35.0) detected in PATH at /usr/bin/geckodriver might not be compatible with the detected firefox version (135.0.1); currently, geckodriver 0.36.0 is recommended for firefox 135.*, so it is advised to delete the driver in PATH and retry

# %%
scraper.alpine_trek(display = True)
# Out:
# The geckodriver version (0.35.0) detected in PATH at /usr/bin/geckodriver might not be compatible with the detected firefox version (135.0.1); currently, geckodriver 0.36.0 is recommended for firefox 135.*, so it is advised to delete the driver in PATH and retry
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>item_name</th>
#       <th>price</th>
#       <th>pecentage_off</th>
#       <th>previous_price</th>
#       <th>img_link</th>
#       <th>item_link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Red Chili Ventic Air Lace Climbing shoes</td>
#       <td>£32.78</td>
#       <td>60%</td>
#       <td>£81.95</td>
#       <td><img src="https://www.bfgcdn.com/out/pictures/generated/product/1/215_215_90/sol_301-0705-0211_pic1_1.jpg" width="150" ></td>
#       <td><a target="_blank" href="https://www.alpinetrek.co.uk/red-chili-ventic-air-lace-climbing-shoes/">https://www.alpinetrek.co.uk/red-chili-ventic-air-lace-climbing-shoes/</a></td>
#     </tr>
#     <tr>
#       <td>C.A.M.P. Head Band System for Titan Large</td>
#       <td>£2.72</td>
#       <td>55%</td>
#       <td>£6.05</td>
#       <td><img src="https://www.bfgcdn.com/out/pictures/generated/product/1/215_215_90/sol_361-0081-0111_pic1_1.jpg" width="150" ></td>
#       <td><a target="_blank" href="https://www.alpinetrek.co.uk/camp-head-band-system-for-titan-large/">https://www.alpinetrek.co.uk/camp-head-band-system-for-titan-large/</a></td>
#     </tr>
#     <tr>
#       <td>C.A.M.P. Head Band System for Titan Small</td>
#       <td>£2.72</td>
#       <td>55%</td>
#       <td>£6.05</td>
#       <td><img src="https://www.bfgcdn.com/out/pictures/generated/product/1/215_215_90/sol_361-0082-0111_pic1_1.jpg" width="150" ></td>
#   'Salewa Ortles Harness Climbing harness ',
#   'Salewa Mountain Spike Crampon Snow spikes ',
#   'NORTEC Alp 2.0 Snow spikes ',
#   'Red Chili Fusion Lv II Climbing shoes ',
#   'Black Diamond ATC-Guide Alpine Belay device ',
#   'Grivel Crampon Safe Crampon bag ',
#   'UnParallel Regulus LV Climbing shoes ',
#   'Black Diamond Hotforge Quickpack Quickdraw ',
#   'Kahtoola EXOspikes Snow spikes ',
#   'Gibbon Slacklines Funline Treewear Set ',
#   'Black Diamond Super 8 Descender ',
#   'DMM Torque Nuts Nut ',
#   'Black Diamond Litewire Quickdraw Quickdraw ',
#   'Black Diamond Litewire Rackpack Snapgate carabiner ',
#   'La Sportiva Mistral Climbing shoes ',
#   'DMM XSRE Lock Captive Bar Gear carabiner ',
#   'Black Diamond Ultralight Ice Screw Ice screw ',
#   'La Sportiva Cobra Climbing shoes ',
#   'Black Diamond Litewire Carabiner Snapgate carabiner ',
#   'Grivel G-SLIDER Ice axe ',
#   'Black Diamond Sabretooth stainless steel Crampons ',
#   'Gibbon Slacklines Classicline XL Slacklining ',
#   'La Sportiva Skwama Climbing shoes ',
#   'Mammut Contact Sling Dyneema 8 mm Sewn runner ',
#   'Edelrid Jay Climbing harness ',
#   'DMM XSRE Mini Carabiner Gear carabiner ',
#   'Black Diamond Camalot C4 Cam ',
#   'Rock Empire Alu Nuts Set Nut ',
#   'Black Diamond Viper Ice tool ',
#   'AustriAlpin HMS Rondo Alu Slide-Autolock HMS carabiner ',
#   'Ocun O-Sling PAD 16 mm Bergfreunde Edition Sewn runner ',
#   'Grivel 2X8 Descender ',
#   'Black Diamond Hotwire Carabiner Snapgate carabiner ',
#   'DMM HB Alloy Offset Nut ',
#   'Black Diamond ATC-Guide Belay device ',
#   'La Sportiva Kids Stickit Climbing shoes ',
#   'Singing Rock Treemouse Throw Bag ',
#   'Edelrid Bulletproof Screw II Screwgate carabiner ',
#   'Edelrid Zodiac 3R Climbing helmet ',
#   'Grivel Master Pro Belay device ',
#   'Mammut Crag Sender Helmet Climbing helmet ',
#   'Wild Country Eos Screwgate carabiner ',
#   'Wild Country Syncro Climbing harness ',
#   'C.A.M.P. Dyon Snapgate carabiner ',
#   'Grivel Air Tech Crampons ',
#   'DMM 11mm Dyneema Rundschlinge Sewn runner ',
#   'DMM Nylon Variable Width Logo Quickdraw Sling Quickdraw sling ',
#   "La Sportiva Women's Solution Climbing shoes ",
#   'Kong Mini D Gear carabiner ',
#   'DMM Vault Wire Gate Gear carabiner ',
#   'DMM Pitcher Rope Bag 26 Rope bag ',
#   'DMM Alpha Sport Quickdraw Quickdraw ',
#   'Climbing Technology Blade Piton ',
#   'AustriAlpin Klebehaken Edelstahl Glue-in bolt ',
#   'Mammut Ophir 3 Slide Climbing harness ',
#   'Petzl Sirocco Climbing helmet ',
#   'Evolv Shaman LV Climbing shoes ',
#   'Petzl Tango 8,5 Half rope ',
#   'Edelrid HMS Bulletproof Triple FG II HMS carabiner ',
#   'DMM Classic Rope Bag 25 Rope bag ',
#   'Black Diamond Solution Harness-Honnold Edition Climbing harness ',
#   'DMM XSRE Wire Gear carabiner ',
#   'AustriAlpin Bolt Lug Set Bolt ',
#   'Kong Paddle Wire Bent Gate Snapgate carabiner ',
#   'AustriAlpin Hanger Plate ',
#   'DMM Dynatec 8 mm Sewn sling ',
#   "La Sportiva Women's Tarantulace Climbing shoes ",
#   'DMM Spectre 2 Snapgate carabiner ',
#   'Gibbon Slacklines Independence Kit Classic Slacklining ',
#   'La Sportiva Miura Climbing shoes ',
#   'DMM Alpha Sport Bent Gate Snapgate carabiner ',
#   'AustriAlpin Micro Snapgate carabiner ',
#   'DMM 11 mm Dyneema Express-Schlinge Quickdraw sling ',
#   "Wild Country Women's Flow 2.0 Climbing harness ",
#   'Mammut 4 Slide Harness Climbing harness ',
#   'Black Diamond Big Air XP Package Belay device ',
#   'DMM PerfectO Schnappkarabiner Snapgate carabiner ',
#   'Black Diamond ATC XP Belay device ',
#   'La Sportiva Katana Laces Climbing shoes ',
#   'DMM Spire Ice axe ',
#   "La Sportiva Women's Miura VS Climbing shoes ",
#   'DMM K-Pro Rope Protector ',
#   'Petzl Club 10,0 Static rope ',
#   'La Sportiva Otaki Climbing shoes ',
#   'Evolv Phantom Climbing shoes ',
#   'DMM Shadow Snapgate carabiner ',
#   'Ocun Pearl Climbing shoes ',
#   "La Sportiva Kid's Gripit Climbing shoes ",
#   'Singing Rock Sicherungsgerät Shuttle Belay device ',
#   'Wild Country Xenon HMS HMS carabiner ',
#   'DMM 26mm Nylon Sewn runner ',
#   'Salewa Attac G3 Via ferrata carabiner ',
#   'Climbing Technology Fly-Weight Evo Alpine Set Quickdraw ',
#   'Blue Ice Choucas Pro Harness Climbing harness ',
#   'Edelrid Chalk Bag Splitter Twist Chalk bag ',
#   'DMM Spectre 2 Colour 6 Pack Snapgate carabiner ',
#   'AustriAlpin HMS Rondo Alu 2-Wege-Autolock HMS carabiner ',
#   'Kahtoola NANOspikes v2 Snow spikes ',
#   "Ocun Kid's Mojo Full-body harness ",
#   'Climbing Technology Multi Chain Evo Daisychain ',
#   "Ocun Women's Twist Tech Eco Climbing harness ",
#   'Grivel Daisy Chain Evo Personal tether ',
#   'DMM Alpha Wire Quickdraw Quickdraw ',
#   'Red Chili Voltage Lace Climbing shoes ',
#   'Tendon Reepschnur 6 mm Cord ',
#   'Climbing Technology Fly-Weight Evo Snapgate carabiner ',
#   'Grivel Axe Guard Pick cover ',
#   "La Sportiva Women's Katana Laces Climbing shoes ",
#   'Wild Country Ropeman MK1F Ascender ',
#   'Ocun Twist Kid Climbing harness ',
#   'Ocun Iris Climbing shoes ',
#   'AustriAlpin Rockit Set Alu Schnapper Quickdraw ',
#   'DMM Shadow Quickdraw Quickdraw ',
#   'DMM Belay Master 2 HMS carabiner ',
#   'Evolv Zenist Pro Climbing shoes ',
#   'DMM 16 mm Nylon Slings Sewn runner ',
#   'DMM Nutbuster Nut removal tool ',
#   "Ocun Women's Webee Lady Climbing harness ",
#   'Ocun Ozone HV Climbing shoes ',
#   'Red Chili Charger Climbing shoes ',
#   'La Sportiva Solution Climbing shoes ',
#   'DMM Phantom Snapgate carabiner ',
#   'Ocun Advancer LU Climbing shoes ',
#   'Petzl Coeur Bolt Stainless Bolt ',
#   'Climbing Technology Truck Gear carabiner ',
#   'La Sportiva Mega Ice Evo Crampons ',
#   'C.A.M.P. Kinetic Gyro Rewind Pro Via ferrata set ',
#   'Mammut 9.5 Crag Dry Rope Single rope ',
#   'La Sportiva Skwama Vegan Climbing shoes ',
#   'Grivel Helmet Duetto Climbing helmet ',
#   'Mammut Wall Rider Climbing helmet ',
#   'Mammut Zopa 9.7 Single rope ',
#   'C.A.M.P. Large Figure 8 Descender ',
#   'DMM Shadow Locking carabiner ',
#   'Ocun Havoc Climbing shoes ',
#   'Wild Country Helium 3.0 Snapgate carabiner ',
#   'DMM Dragonfly Micro Cams Cam ',
#   'Mammut Comfort Fast Adjust Harness Climbing harness ',
#   "Climbing Technology Women's Anthea Climbing harness ",
#   'DMM Shadow Bent Gate Snapgate carabiner ',
#   'Salewa HMS Screw G2 HMS carabiner ',
#   'La Sportiva Katana Climbing shoes ',
#   'DMM XSRE Lock Gear carabiner ',
#   'DMM Dragonfly Offsets Cam ',
#   'Blue Ice Aero Lite Ice screw ',
#   'Beal Ice Line Golden Dry 8,1 mm Half rope ',
#   'Evolv Zenist Climbing shoes ',
#   'La Sportiva Tarantula Climbing shoes ',
#   'Wild Country Session Quickdraw Quickdraw ',
#   'Petzl Boreo Climbing helmet ',
#   'La Sportiva Tarantulace Climbing shoes ',
#   'C.A.M.P. Photon Mixed Express KS Quickdraw ',
#   'DMM Alpha Wire Snapgate carabiner ',
#   'Mantle Latex Band Exercise band ',
#   'Petzl Anneau Sewn sling ',
#   'DMM Ultra O Locking carabiner ',
#   'Black Diamond Express Ice Screw Ice screw ',
#   'DMM Alpha Sport Straight Gate Snapgate carabiner ',
#   'Wild Country Friend Set Cam ',
#   'DMM Phantom Screwgate carabiner ',
#   'Blue Ice Sender Chalk bag ',
#   'Petzl Caritool Gear carabiner ',
#   'Wild Country Friend Cam ',
#   "Mammut Women's Ophir Fast Adjust Climbing harness ",
#   'Wild Country Revo Belay Device Belay device ',
#   'C.A.M.P. Dyon Express KS Quickdraw ',
#   'Scarpa Furia Air Climbing shoes ',
#   'Metolius Feather Nut Tool Nut removal tool ',
#   'Grivel Ice Axe Gzero Ice axe ',
#   'DMM Shadow/Spectre Hybrid Quickdraw Quickdraw ',
#   'DMM Shadow HMS HMS carabiner ',
#   'Salewa Alpinist Pro Crampons ',
#   'La Sportiva Mythos Eco Climbing shoes ',
#   'Rock Empire DynaGo Via ferrata set ',
#   'Scarpa Instinct VSR Climbing shoes ',
#   'Singing Rock Footer Complete ',
#   'Ocun Advancer QC Climbing shoes ',
#   'Scarpa Origin VS Climbing shoes ',
#   'Blue Ice Choucas Light Climbing harness ',
#   'Evolv Phantom LV Climbing shoes ',
#   'Petzl Lynx Crampons ',
#   'Beal Booster III Golden dry 9,7 mm Single rope ',
#   'Climbing Technology Orbiter F Rope pulley ',
#   'DMM Deadman Snow anchor ',
#   'Ocun Osprey Triple Locking carabiner ',
#   'Mammut 7.5 Alpine Sender Dry Rope Half rope ',
#   'DMM Phantom Colour 6 Pack Snapgate carabiner ',
#   'Salewa Express Set Dyn Hot G3 Straight/Bent Quickdraw ',
#   'Beal Ice Line 8,1 mm Half rope ',
#   'Blue Ice Aero Ice screw ',
#   'Beal Tiger 10 mm Single rope ',
#   'DMM Dragon 2 Cam ',
#   'Beal Back Up Line 5 mm Cord ',
#   'Mammut Belay Sling 19.0 Personal tether ',
#   'Salewa Express Set Dyn Hot G3 Straight/Wire Quickdraw ',
#   'Grivel Monte Bianco Ice axe ',
#   'DMM PerfectO Verschlusskarabiner Locking carabiner ',
#   'AustriAlpin Steigeisengurt ',
#   'Climbing Technology Concept TG HMS carabiner ',
#   'Blue Ice Hydra Leash ',
#   'Beal Legend 8.3 Half rope ',
#   'Beal Tiger 10 mm Golden Dry Single rope ',
#   'Beal Booster III 9,7 mm Single rope ',
#   'DMM Grippy Grip Tape ',
#   'Mammut Zephir Altitude Climbing harness ',
#   'Petzl Multihook Haken ',
#   'Gibbon Slacklines Slackrack Classic Slacklining ',
#   'Beal Joker 9,1 mm Single rope ',
#   'Grivel Helix Ice screw ',
#   'Rock Empire Streak Lady Red Climbing harness ',
#   'Blue Ice Cuesta ADJ Harness Climbing harness ',
#   'Grivel Plume Nut K3N Screwgate carabiner ',
#   'Beal Escaper ',
#   'Grivel Master Pro Belayer Kit Belay device ',
#   'Grivel G12 Crampons ',
#   'DMM Alpha Trad Snapgate carabiner ',
#   'La Sportiva Testarossa Climbing shoes ',
#   'Wild Country Session Bent Gate Snapgate carabiner ',
#   'Petzl Contact 9.8 Single rope ',
#   'Black Diamond Camalot Ultralight Cam ',
#   'Blue Ice Choucas Harness Climbing harness ',
#   'Grivel Crampons G20 Plus Com Crampons ',
#   'Beal Top Gun II 10,5 mm Single rope ',
#   'Beal Zenith 9.5 Single rope ',
#   'Wild Country Session Screw Gate Screwgate carabiner ',
#   'Beal Cobra II 8,6mm Half rope ',
#   'Petzl Split Rope bag ',
#   'Ocun Falcon QuickDraw Polyamide 16mm Quickdraw ',
#   'Ocun Webee Chest Lite + Tie-In Sling Chest harness ',
#   'Wild Country Stainless steel Pro Key Nut removal tool ',
#   'C.A.M.P. Tricam Evo Cam ',
#   'Blue Ice Addax Harness Climbing harness ',
#   'C.A.M.P. Corsa Alpine Ice axe ',
#   'Mammut 9.0 Alpine Sender Dry Rope Single rope ',
#   'Petzl Corax LT Climbing harness ',
#   'Ocun QD Set Hawk Combi Pad 16 Quickdraw ',
#   'Wild Country Rockcentrics Dyneema Nut ',
#   'Petzl Voltige Chest harness ',
#   'Petzl Ersatzpolster Helme Climbing helmet ',
#   'Beal Rando Golden Dry 8 mm Twin rope ',
#   'C.A.M.P. Start Rappel Glove Full Finger Gloves ',
#   'Wild Country Super Light Offset Rock Nut ',
#   'Mad Rock Shark 2.0 Climbing shoes ',
#   'Blue Ice Solo Leash ',
#   'Grivel Explorer Light Snow spikes ',
#   'Beta Climbing Designs Evo Sport Super Standard Clip stick ',
#   'Petzl Mambo 10.1 Single rope ',
#   'Edelrid Basis Cable Kit Special Via ferrata set ',
#   'C.A.M.P. Photon Wire Express KS Dyneema Quickdraw ',
#   'Ocun Hurry Belay device ',
#   'C.A.M.P. Energy CR 3 Climbing harness ',
#   "La Sportiva Women's Miura Climbing shoes ",
#   'Petzl Quark Ice Tool Ice tool ',
#   'Petzl GriGri + Belay device ',
#   'Grivel Ice Screw 360° Ice screw ',
#   'C.A.M.P. Flint Climbing harness ',
#   'Ocun Hawk Screw Screwgate carabiner ',
#   'Gibbon Slacklines Tree Wear XL Tree protection ',
#   'NORTEC Alp Forest Snow spikes ',
#   "Scarpa Women's Helix Climbing shoes ",
#   'Beta Climbing Designs Evo Sport Ultra Compact Clip stick ',
#   'C.A.M.P. Steel Oval Lock -Stahlkarabiner Steel carabiner ',
#   'Ocun Kestrel Snapgate carabiner ',
#   'Singing Rock Cambiumschoner Jingle II Sewn sling ',
#   'Beal Be Lock Screwgate carabiner ',
#   'Boreal Joker Climbing shoes ',
#   'Ocun Falcon Bent Snapgate carabiner ',
#   'Tendon Pro Work 11 Static rope ',
#   'blue pill Extrem Boulder Climbing holds ',
#   'Petzl Ange S Snapgate carabiner ',
#   'Wild Country Session Straight Gate Snapgate carabiner ',
#   'Beal Zest Expresse Quickdraw ',
#   'Blue Ice Pick / Adze Protector Gear protector ',
#   'Wild Country Rocks on Wire Nut ',
#   'Petzl Trigrest ',
#   "Petzl Pur'Anneau Sewn sling ",
#   'Climbing Technology Thunder Hammer Kit ',
#   'Ocun Belay Set Condor Triple/Hurry Belay device ',
#   'Boreal Beta Graphite Climbing shoes ',
#   'blue pill Small Mix Climbing holds ',
#   'Scarpa Helix Climbing shoes ',
#   'Tendon Pro Work 10.5 Static rope ',
#   'Climbing Technology Fly-Weight Evo Set Quickdraw ',
#   'Beal Opera 8.5 Golden Dry Single rope ',
#   'Kong HMS Napik Screw HMS carabiner ',
#   'Tendon Alpine 7.9 C.I.A.P Half rope ',
#   'Tendon Master 7,8 mm Shield Half rope ',
#   'Petzl Gully Ice Axe Ice axe ',
#   'Wild Country Classic Rock Nut ',
#   'C.A.M.P. Knifeblade Piton ',
#   'Petzl Cord Tec Ersatzreepschnur ',
#   'Scarpa Chimera Climbing shoes ',
#   "Beal Transf'Air Twin B Rope pulley ",
#   'Grivel K5N DELTA Screw Lock Screwgate carabiner ',
#   'Climbing Technology Ice Screw Ice screw ',
#   'Snap Pad Flap Crashpad carrying system ',
#   'C.A.M.P. Frost Snow spikes ',
#   'C.A.M.P. Orbit Lock Screwgate carabiner ',
#   'Petzl Laser Speed Light Ice screw ',
#   'Edelrid Pure Set II Quickdraw ',
#   'Beal Opera 8,5 mm Single rope ',
#   'Wild Country Rocks on Wire Set 1-10 Nut ',
#   'Climbing Technology Lycan Crampons ',
#   'Edelrid PES Sling 3R 16 mm Sewn sling ',
#   'Blue Ice Akila Adze Technical Piolet Ice axe ',
#   'Petzl Trigrest ',
#   'Petzl Laser Ice screw ',
#   'Petzl Vasak Front Sections ',
#   'Petzl Summit Ice axe ',
#   'Petzl Neox Belay device ',
#   'Singing Rock Rama Belay device ',
#   "Beal Transf'Air Fixe Rope pulley ",
#   'Climbing Technology Twister ',
#   "Red Chili Kid's Pulpo Climbing shoes ",
#   'C.A.M.P. XLC Nanotech Crampons ',
#   'Petzl Sarken Front Sections ',
#   'Petzl Irvis Crampons ',
#   'Climbing Technology Fixit L ',
#   'Petzl Dart Front Sections ',
#   'Edelrid Bulletproof Set II Quickdraw ',
#   'Edelrid Pure Wire III Snapgate carabiner ',
#   'La Sportiva Futura Climbing shoes ',
#   'Petzl Cord-Tec Kit ',
#   'Ocun Via Ferrata Twist Set Climbing set ',
#   'Climbing Technology Lime Screwgate Bergfreunde Edition Screwgate carabiner ',
#   'Petzl Dart Crampons ',
#   'Petzl Bongo Rock hammer ',
#   'Petzl Ultra-Light Crampon Bag Crampon bag ',
#   'La Sportiva Miura VS Climbing shoes ',
#   'Petzl Irvis Hybrid Crampons ',
#   'Petzl Summit Evo Ice axe ',
#   'Tendon Master 7,8 mm Half rope ',
#   'Petzl Gemini Rope pulley ',
#   'Petzl Vasak Crampons ',
#   'Climbing Technology Ice Hook Quickdraw ',
#   'Petzl Mini Rope pulley ',
#   'Crafty Climbing Hangboard Ruby Training board ',
#   'Mad Rock Duo Pad Crash pad ',
#   'Petzl Fifi Hook ',
#   'Beal Be Safe HMS carabiner ',
#   'Climbing Technology North Couloir Ice Axe Ice tool ',
#   'Mammut Cord POS Cord ',
#   'Blue Ice Hummingbird Ice Axe Ice axe ',
#   'Edelrid SE Priti 9,6 mm Single rope ',
#   'Snap Pad Bundle ',
#   'Petzl Footcord Foot loop sling ',
#   'C.A.M.P. Universal Piton ',
#   'Edelrid Mission Set II Quickdraw ',
#   'Petzl Conga 8 mm Cord ',
#   'Tenaya Tarifa Climbing shoes ',
#   'Petzl Fil Flex Small Crampons ',
#   'Petzl Pulse Removable Anchor Bolt ',
#   'Mammut Wall Rider MIPS Climbing helmet ',
#   'Singing Rock Safety Chain Daisychain ',
#   'Scarpa Instinct Lace Climbing shoes ',
#   'Tenaya Oasi LV Climbing shoes ',
#   'UnParallel NewTro Lace Climbing shoes ',
#   'Gonso Seat Cream ',
#   'Tenaya Mundaka Climbing shoes ',
#   'Tenaya Masai Climbing shoes ',
#   'Petzl Fakir Crampon bag ',
#   "Petzl Goutte D'Eau ",
#   "Scarpa Women's Origin Climbing shoes ",
#   'Tenaya Iati Climbing shoes ',
#   'Edelrid Starling Pro Dry 8.2 mm Half rope ',
#   'Edelrid Hudson Hammer ',
#   "Arc'teryx Women's Skaha Harness Climbing harness ",
#   'Edelrid Performance Static 10,0 mm Static rope ',
#   'Edelrid Swift Protect Pro Dry 8,9 Single rope ',
#   'UnParallel Regulus Climbing shoes ',
#   'Evolv Kronos Climbing shoes ',
#   'Mammut Sender Brush Bouldering brush ',
#   'KMZ Holds Spax 1 - Set of 22 climbing holds Set of 22 climbing holds ',
#   'DMM Vault Wire Gear carabiner ',
#   "La Sportiva Women's Skwama Vegan Climbing shoes ",
#   "UnParallel Women's Flagship LV Climbing shoes ",
#   'Grivel Ice Axe Long Leash Evo Leash ',
#   "La Sportiva Women's Aragon Climbing shoes ",
#   'Rock Empire Equip Belt Climbing harness ',
#   'La Sportiva Miura VS Climbing shoes ',
#   'Salewa Pura Helmet Climbing helmet ',
#   'Edelrid HMS Bullet Permalock HMS carabiner ',
#   'Red Chili Sausalito IV Climbing shoes ',
#   'Wild Country Mosquito Climbing harness ',
#   'Scarpa Vapor V Climbing shoes ',
#   'Ropeless Tape + Dose Tape ',
#   'Red Chili Ventic Air Lace Climbing shoes ',
#   'Crafty Climbing Five Toothed Monster Chalk Bag Chalk bag ',
#   'Gibbon Slacklines Classicline XL Treewear Set ',
#   'Tenaya Inti Climbing shoes ',
#   'La Sportiva Futura Climbing shoes ',
#   'UnParallel NewTro VCS Climbing shoes ',
#   'Rock Empire Chackan Ski Ice axe ',
#   'NORTEC Trail 2.1 Snow spikes ',
#   'AustriAlpin Ovalo 3-Wege Autolock Locking carabiner ',
#   'Crafty Climbing Bat Chalk Bag Chalk bag ',
#   'Crafty Climbing Furry Chalk Bag Chalk bag ',
#   'Black Diamond Serac stainless steel Crampons ',
#   'DMM Phantom Quickdraw Quickdraw ',
#   'Black Diamond Contact Crampons ',
#   'Climbing Technology Lime SG Screwgate carabiner ',
#   'Ropeless Cheers Brush Bouldering brush ',
#   'DMM Revolver Snapgate carabiner ',
#   'AustriAlpin HMS Rondo Alu Schrauber Selfie HMS carabiner ',
#   'Ocun Ladder H-Step Foot loop sling ',
#   'La Sportiva Tarantula Boulder Climbing shoes ',
#   'Edelrid Loopo Lite II Climbing harness ',
#   'C.A.M.P. Energy Climbing harness ',
#   'Wild Country Wildwire 2 Quickdraw Quickdraw ',
#   'Climbing Technology Tank Evo 25 Rope bag ',
#   'Climbing Technology Sport Chain Daisychain ',
#   "Salewa Kid's Rookie FB Full-body harness ",
#   'Ocun Twist Quattro Climbing harness ',
#   'Ocun Ozone Climbing shoes ',
#   'Gibbon Slacklines Bananalama XL Treewear Set Slacklining ',
#   'Ocun Sigma Climbing shoes ',
#   'C.A.M.P. Rocky Carpet - Rope Tarpaulin Rope Tarpaulin ',
#   'Climbing Technology Tricky Tool Clipping aid ',
#   'Beal Jampa Single rope ',
#   'Evolv Shaman Climbing shoes ',
#   'AustriAlpin SR1200 Rope pulley ',
#   'NORTEC Nordic Snow spikes ',
#   'Edelrid Performance Static 10,5 mm Static rope ',
#   'La Sportiva Aragon Climbing shoes ',
#   'AustriAlpin Rockit Light Set Quickdraw ',
#   'La Sportiva Solution Comp Climbing shoes ',
#   'Scarpa Veloce Climbing shoes ',
#   '8bplus Stan Chalk bag ',
#   'Climbing Technology Wall Harness Climbing harness ',
#   'Ocun Striker LU Climbing shoes ',
#   'Kong Duck Ascender ',
#   '8bplus Jamie Chalk bag ',
#   '8bplus Charlie Chalk bag ',
#   '8bplus AJ Chalk bag ',
#   '8bplus Bruno Chalk bag ',
#   "Scarpa Kid's Piki J Climbing shoes ",
#   'Ocun Jett QC Climbing shoes ',
#   "Rock Empire Kid's Hopi Climbing harness ",
#   '8bplus Donald Chalk bag ',
#   'Scarpa Instinct S Climbing shoes ',
#   'Ocun Ladder D-Step Foot loop sling ',
#   'Metolius Prime Rib Training board ',
#   'Wild Country Syncro Helmet Climbing helmet ',
#   '8bplus Manny Chalk bag ',
#   'Metolius Mega Pack 30 Climbing holds ',
#   '8bplus Moritz Chalk bag ',
#   '8bplus Felix Chalk bag ',
#   'La Sportiva Genius Climbing shoes ',
#   'Rock Empire Kanrei Climbing shoes ',
#   'Rock Empire Comet Cam ',
#   '8bplus Marty Chalk bag ',
#   'Ocun Jett LU Climbing shoes ',
#   'Ocun Striker QC Climbing shoes ',
#   'Singing Rock Liquid Chalk (Magnesium) Chalk ',
#   '8bplus Phil Chalk bag ',
#   'Ocun Bullit Climbing shoes ',
#   'Metolius Wood Grips 5 Pack Climbing holds ',
#   'Grivel Explorer Snow spikes ',
#   'AustriAlpin Micro Wire 6er Set Alu Snapgate carabiner ',
#   'Grivel Lambda Twin Lock HMS carabiner ',
#   'Kong HMS Classic Autoblock HMS carabiner ',
#   'Edelrid Pure Screw III Screwgate carabiner ',
#   'Beal Dynaloop Sewn sling ',
#   'Ocun ST-Sling DYN 12mm Quickdraw sling ',
#   'DMM Revolver Locking carabiner ',
#   'Beal Stinger III Golden Dry 9.4 mm Single rope ',
#   'So iLL The Street LV Climbing shoes ',
#   'Blue Ice Harfang Alpine Hybrid Crampons ',
#   'La Sportiva Mantra Climbing shoes ',
#   'AustriAlpin Prinz Noteisgerät Ice tool ',
#   'Beal Reepschnur Cord ',
#   'Wataaah Big Brushy with File Bouldering brush ',
#   "La Sportiva Kid's Tarantula JR Climbing shoes ",
#   'Beal Cobra II 8,6mm Golden Dry Half rope ',
#   'Boreal Manos Grip trainer ',
#   'Nature Climbing Originals Climbing hold ',
#   'Beal Karma 9.8 Single rope ',
#   'Beal Wallmaster Indoor rope ',
#   'Salewa Ortles Master Cord Precut Cord ',
#   'Wataaah Big Brushy Bouldering brush ',
#   'Climbing Technology Alp Loop Sewn sling ',
#   "Petzl Women's Corax LT Climbing harness ",
#   'Mammut Sender Harness Climbing harness ',
#   'Petzl Aquila Climbing harness ',
#   '8bplus Hector Chalk bag ',
#   'Petzl Arial 9,5 Single rope ',
#   'Beal Bambi II Full-body harness ',
#   'Grivel Air Tech Evo Ice axe ',
#   'Petzl Fly Climbing harness ',
#   'Beal Gully 7,3 Half rope ',
#   'Petzl Alto Crash pad ',
#   'Beal Dynadoubleclip - 40 / 75 cm 40 / 75 cm ',
#   'NORTEC Easy Snow spikes ',
#   '8bplus Herman - Boulder Bag Boulder Bag ',
#   'Mammut 9.9 Crag Workhorse Dry Rope Single rope ',
#   'Petzl Paso Guide Half rope ',
#   'Petzl Caritool Evo Ice screw holster ',
#   'Grivel Air Tech Light Crampons ',
#   'Petzl Komplettgurt 8003 Full-body harness ',
#   'Mammut 9.5 Crag Classic Rope Single rope ',
#   '8bplus Maxwell Chalk bag ',
#   'C.A.M.P. Nutkey Nut removal tool ',
#   'Beal Jammy Sewn sling ',
#   'Mad Rock Redline Strap Climbing shoes ',
#   'Salewa Alpinist Combi Crampons ',
#   'Wild Country Helium 3.0 Quickdraw Quickdraw ',
#   'Petzl Connect Adjust Personal tether ',
#   'Climbing Technology Swhippy Y Leash ',
#   'Singing Rock Kletterhelm Hex Climbing helmet ',
#   'TheraBand Flexible Exercise Bar Training device ',
#   'Scarpa Origin Climbing shoes ',
#   'Climbing Technology Ascent Climbing harness ',
#   "Scarpa Women's Instinct Lace Climbing shoes ",
#   'Blue Ice Bluebird Ice Axe Ice axe ',
#   'Scarpa Vapor Climbing shoes ',
#   'Nature Climbing Stoak Board II Training board ',
#   'Crimp Oil Original Skin-care oil ',
#   'Climbing Technology Otto Curved Descender ',
#   'C.A.M.P. Ball Nuts Cam ',
#   'Climbing Technology Concept SG HMS carabiner ',
#   'Petzl Rocpec Hand drill ',
#   'Petzl Quickstep Ladder ',
#   'Petzl Mini Traxion Rope pulley ',
#   "Slackline-Tools Air'n Jump Slacklining ",
#   'Petzl Laser Speed Ice screw ',
#   'C.A.M.P. Lost Arrow Piton ',
#   'C.A.M.P. Skimo Race Crampons ',
#   'Petzl Ergonomic Ice Tool Ice tool ',
#   'Petzl Ultralegere Rope pulley ',
#   'Slackline-Tools 45 m SlackTivity Set Slacklining ',
#   'Petzl Leopard LLF Crampons ',
#   'Petzl Gradistep Ladder ',
#   'Petzl Finesse Sling Quickdraw sling ',
#   'C.A.M.P. Corsa Nanotech Ice axe ',
#   "Slackline-Tools Kids 'n Slack Set 10 Slacklining ",
#   "Slackline-Tools Clip'n Slack Set 10 m Slacklining ",
#   'Tenaya Arai Climbing shoes ',
#   'Crafty Climbing Hangboard Topaz Training board ',
#   'C.A.M.P. Climbing Tape Tape ',
#   'Tenaya Indalo Climbing shoes ',
#   'C.A.M.P. Neve Ice axe ',
#   'Boreal Alpha Climbing shoes ',
#   'Tendon Smart Lite 9,8 mm Single rope ',
#   'C.A.M.P. Alpine Flash Climbing harness ',
#   'Grivel Candela Ice screw tool ',
#   'TheraBand Exercise Band Exercise band ',
#   'Tenaya Tanta Climbing shoes ',
#   'C.A.M.P. Andry Rope pulley ',
#   'Scarpa Force Climbing shoes ',
#   'Petzl Flex ',
#   'Beal Rando 8 mm Twin rope ',
#   'UnParallel Pivot Climbing shoes ',
#   'Stoic HulanSt. Snow Spikes Snow spikes ',
#   "Scarpa Women's Vapor S Climbing shoes ",
#   'Scarpa Boostic Climbing shoes ',
#   'Mad Rock Drone High Volume Comp Series Climbing shoes ',
#   'AustriAlpin Papnu Chalk Bag Chalk bag ',
#   'Black Diamond Lock Down Leash Leash ',
#   'Petzl Omni Screw-Lock Screwgate carabiner ',
#   'Snap Big Chalk Bag Chalk bag ',
#   "Arc'teryx Women's C-Quence Harness Climbing harness ",
#   'DMM Halfnut Nut ',
#   'Nature Climbing Raw Granite Screw On Climbing holds ',
#   'Ocun Hawk QuickDraw Zoom Polyamide 15/22mm Quickdraw ',
#   'Stoic AlandSt Climbing shoes ',
#   'Slackline-Tools 15 m SlackTivity Set Slacklining ',
#   'UnParallel Flagship Pro Climbing shoes ',
#   '8bplus Chalk Bomb Chalk ',
#   'UnParallel Qubit Climbing shoes ',
#   'Five Ten Niad Lace Climbing shoes ',
#   'Rock Empire DynaGo Via ferrata set ',
#   'Edelrid Pure Triple III Locking carabiner ',
#   'C.A.M.P. Head Band System for Titan Large ',
#   'Ocun Crack Gloves Crack gloves ',
#   'Nature Climbing Raw Chalk Chalk ',
#   "Boreal Women's Joker Climbing shoes ",
#   'Boreal Ninja Climbing shoes ',
#   'Boreal Satori Climbing shoes ',
#   'Edelrid SM Clip Ice screw racking clip ',
#   'Scarpa Booster Climbing shoes ',
#   'E9 E9 WoodyB Bouldering brush ',
#   'Grivel Harness Trend Climbing harness ',
#   'Scarpa Furia S Climbing shoes ',
#   'Edelrid Performance Static 11.0 mm 1-seit Endv. Static rope ',
#   'Edelrid Boa Gym 9,8 mm Single rope ',
#   'Edelrid Agent Chest harness ',
#   'Edelrid Performance Static 11,0 mm Static rope ',
#   'Edelrid HMS Strike Triple II HMS carabiner ',
#   "Boreal Kid's Ninja Junior Climbing shoes ",
#   'C.A.M.P. Matik Belay device ',
#   'Wild Country Session Climbing harness ',
#   'UnParallel Flagship Climbing shoes ',
#   'Gibbon Slacklines Flowline Treewear Set ',
#   'Climbing Technology Tami Climbing harness ',
#   'So iLL Street RV Climbing shoes ',
#   'Ocun Bodyguard Full-body harness ',
#   'KMZ Holds Giga 3 Climbing hold ',
#   'Climbing Technology Ice Classic Crampons ',
#   'Climbing Technology Explorer Harness Climbing harness ',
#   'Grivel Rubber Point Protector Pick cover ',
#   'TheraBand CLX Band Exercise band ',
#   'Metolius Mega Pack 40 Climbing holds ',
#   "Metolius Bamboo Boar's Hair Brush Bouldering brush ",
#   'Metolius Wood Grips 25er Pack Climbing holds ',
#   '8bplus Bobo Chalk bag ',
#   'Scarpa Reflex V Climbing shoes ',
#   'Metolius Greatest Chips Screw On Climbing holds ',
#   'Max Climbing Spinchboard Training board ',
#   'Mammut 8.0 Alpine Dry Rope Half rope ',
#   'C.A.M.P. Liquid Chalk Chalk ',
#   '8bplus Boulder Brush Wazl Bouldering brush ',
#   'Wataaah Big Brushy Deluxe Bouldering brush ',
#   'Beal Hands Up Ascender ',
#   'Petzl Nomic Ice Tool Ice tool ',
#   'C.A.M.P. Head Protector - Ice pick accessories Ice pick accessories ',
#   'Kong Express Frog Clipping aid ',
#   'Salewa Rockhammer Rock hammer ',
#   'C.A.M.P. Kit Ferrata Kinetic Rewind Energy CR 4 Via ferrata set ',
#   'Evolv Defy Climbing shoes ',
#   'AustriAlpin skyClimb Crampons ',
#   'Evolv Magic Hand Tape II Tape ',
#   'NORTEC Fast Snow spikes ',
#   'Petzl Masselottes ',
#   'Climbing Technology Fixit S ',
#   'Petzl Leopard FL Crampons ',
#   'Petzl Mini Marteau Replacement hammer ',
#   "Scarpa Kid's Reflex Climbing shoes ",
#   'Petzl Aven Climbing harness ',
#   'Edelrid Ace II Climbing harness ',
#   'Black Diamond Method S Climbing Shoes Climbing shoes ',
#   'UnParallel TN Pro Climbing shoes ',
#   "Edelrid Women's Autana Climbing harness ",
#   'Five Ten Niad Moccasym Climbing shoes ',
#   'Edelrid Eddy Belay device ',
#   'Wataaah Terrence Climbing holds ',
#   'Scarpa Velocity Climbing shoes ',
#   "Five Ten Women's Niad Lace Climbing shoes ",
#   'Rock Empire Shogun Climbing shoes ',
#   'Edelrid Tommy Caldwell Eco Dry DT 9,6 Single rope ',
#   'Edelrid Dyneema Express Sling 11mm II Quickdraw sling ',
#   'UnParallel Shoe L5 UP Approach shoes ',
#   'Climbing Technology Mini Crampon 4 P Snow spikes ',
#   'Metolius Bouldering Set Naturals Climbing holds ',
#   'Climbing Technology Eclipse Climbing helmet ',
#   'C.A.M.P. Oval XL Snapgate carabiner ',
#   "Scarpa Women's Generator V Climbing shoes ",
#   'Crimp Oil Arnica Skin-care oil ',
#   'Climbing Technology Hammer Lodge Gear carabiner ',
#   'Grivel Black Hole Ice screw cover ',
#   'Mammut Gym Print Chalk Bag Chalk bag ',
#   "Evolv Women's Geshido Climbing shoes ",
#   'Edelrid Shark Soft Crampons ',
#   'Edelrid Pure Pro Set Quickdraw ',
#   'Stoic ÅlandSt. Leather Climbing shoes ',
#   "UnParallel Kid's UP Climbing shoes ",
#   'Petzl Fangleine V Link Leash ',
#   'UnParallel Sirius Lace LV Climbing shoes ',
# ...
#   'https://www.alpinetrek.co.uk/salewa-alpinist-combi-crampons/',
#   'https://www.alpinetrek.co.uk/wild-country-helium-30-quickdraw-quickdraw/',
#   'https://www.alpinetrek.co.uk/petzl-connect-adjust-personal-tether/',
#   'https://www.alpinetrek.co.uk/climbing-technology-swhippy-y-leash/',
#   'https://www.alpinetrek.co.uk/singing-rock-kletterhelm-hex-climbing-helmet/',
#   'https://www.alpinetrek.co.uk/theraband-flexible-exercise-bar-training-device/',
#   'https://www.alpinetrek.co.uk/scarpa-origin-climbing-shoes/',
#   'https://www.alpinetrek.co.uk/climbing-technology-ascent-climbing-harness/',
#   'https://www.alpinetrek.co.uk/scarpa-womens-instinct-lace-climbing-shoes/',
#   'https://www.alpinetrek.co.uk/blue-ice-bluebird-ice-axe-ice-axe/',
#   'https://www.alpinetrek.co.uk/scarpa-vapor-climbing-shoes/',
#   'https://www.alpinetrek.co.uk/nature-climbing-stoak-board-ii-training-board/',
#   'https://www.alpinetrek.co.uk/crimp-oil-original-skin-care-oil/',
#   'https://www.alpinetrek.co.uk/climbing-technology-otto-curved-descender/',
#   'https://www.alpinetrek.co.uk/camp-ball-nuts-cam/',
#   'https://www.alpinetrek.co.uk/climbing-technology-concept-sg-hms-carabiner/',
#   'https://www.alpinetrek.co.uk/petzl-rocpec-hand-drill/',
#   'https://www.alpinetrek.co.uk/petzl-quickstep-ladder/',
#   'https://www.alpinetrek.co.uk/petzl-mini-traxion-rope-pulley/',
#   'https://www.alpinetrek.co.uk/slackline-tools-airn-jump-slacklining/',
#   'https://www.alpinetrek.co.uk/petzl-laser-speed-ice-screw/',
#   'https://www.alpinetrek.co.uk/camp-lost-arrow-piton/',
#   'https://www.alpinetrek.co.uk/camp-skimo-race-crampons/',
#   'https://www.alpinetrek.co.uk/petzl-ergonomic-ice-tool-ice-tool/',
#   'https://www.alpinetrek.co.uk/petzl-ultralegere-rope-pulley/',
#   'https://www.alpinetrek.co.uk/slackline-tools-45-m-slacktivity-set-slacklining/',
#   'https://www.alpinetrek.co.uk/petzl-leopard-llf-crampons/',
#   'https://www.alpinetrek.co.uk/petzl-gradistep-ladder/',
#   'https://www.alpinetrek.co.uk/petzl-finesse-sling-quickdraw-sling/',
#   'https://www.alpinetrek.co.uk/camp-corsa-nanotech-ice-axe/',
#   'https://www.alpinetrek.co.uk/slackline-tools-kids-n-slack-set-10-slacklining/',
#   'https://www.alpinetrek.co.uk/slackline-tools-clipn-slack-set-10-m-slacklining/',
#   'https://www.alpinetrek.co.uk/tenaya-arai-climbing-shoes/',
#   'https://www.alpinetrek.co.uk/crafty-climbing-hangboard-topaz-training-board/',
#   'https://www.alpinetrek.co.uk/camp-climbing-tape-tape-bf/',
#   'https://www.alpinetrek.co.uk/tenaya-indalo-climbing-shoes/',
#   'https://www.alpinetrek.co.uk/camp-neve-ice-axe/',
#   'https://www.alpinetrek.co.uk/boreal-alpha-climbing-shoes/',
#   'https://www.alpinetrek.co.uk/tendon-smart-lite-98-mm-single-rope/',
#   'https://www.alpinetrek.co.uk/camp-alpine-flash-climbing-harness/',
#   'https://www.alpinetrek.co.uk/grivel-candela-ice-screw-tool/',
#   'https://www.alpinetrek.co.uk/theraband-exercise-band-exercise-band/',
#   'https://www.alpinetrek.co.uk/tenaya-tanta-climbing-shoes/',
#   'https://www.alpinetrek.co.uk/camp-andry-rope-pulley/',
#   'https://www.alpinetrek.co.uk/scarpa-force-climbing-shoes/',
#   'https://www.alpinetrek.co.uk/petzl-flex/',
#   'https://www.alpinetrek.co.uk/beal-rando-8-mm-twin-rope/',
#   'https://www.alpinetrek.co.uk/unparallel-pivot-climbing-shoes/',
#   'https://www.alpinetrek.co.uk/stoic-hulanst-snow-spikes-snow-spikes/',
#   'https://www.alpinetrek.co.uk/scarpa-womens-vapor-s-climbing-shoes/',
#   'https://www.alpinetrek.co.uk/scarpa-boostic-climbing-shoes/',
#   'https://www.alpinetrek.co.uk/mad-rock-drone-high-volume-comp-series-climbing-shoes/',
#   'https://www.alpinetrek.co.uk/austrialpin-papnu-chalk-bag-chalk-bag/',
#   'https://www.alpinetrek.co.uk/black-diamond-lock-down-leash-leash/',
#   'https://www.alpinetrek.co.uk/petzl-omni-screw-lock-screwgate-carabiner/',
#   'https://www.alpinetrek.co.uk/snap-big-chalk-bag-chalk-bag/',
#   'https://www.alpinetrek.co.uk/arcteryx-womens-c-quence-harness-climbing-harness/',
#   'https://www.alpinetrek.co.uk/dmm-halfnut-nut/',
#   'https://www.alpinetrek.co.uk/nature-climbing-raw-granite-screw-on-climbing-holds/',
#   'https://www.alpinetrek.co.uk/ocun-hawk-quickdraw-zoom-polyamide-15-22mm-quickdraw/',
#   'https://www.alpinetrek.co.uk/stoic-alandst-climbing-shoes/',
#   'https://www.alpinetrek.co.uk